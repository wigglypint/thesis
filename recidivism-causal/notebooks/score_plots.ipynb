# %%
from pathlib import Path
import pandas as pd
import numpy as np

#set project root as .../recidivism-causal
project_root = Path("/dcs/23/u2200504/thesis/recidivism-causal").resolve()

#set causal pitfalls root
cp_root = project_root / "data" / "raw" / "CausalPitfallsData"
#test it works
cp_root

score_dir = project_root/"results"/"scores"

# %%
files = {
    "dagbagm": score_dir/"scores_dagbagm.csv",
    "dagslam": score_dir/"scores_dagslam.csv",
    "fci": score_dir/"scores_fci.csv",
    "hc": score_dir/"scores_hc.csv",
    "lim": score_dir/"scores_lim.csv",
    "rex": score_dir/"scores_rex.csv"
}

dfs = []
for algo, path in files.items():
    df = pd.read_csv(path)
    dfs.append(df)

all_scores = pd.concat(dfs, ignore_index=True, sort=False)

# %%
all_scores_path = score_dir / "scores_all_algos.csv"
all_scores.to_csv(all_scores_path, index=False)

# %%
all_scores = all_scores.sort_values(
    by=["dataset", "algo"], ascending=[True, True]
).reset_index(drop=True)

all_scores.head()
# Out:
#     TP   FP   FN   TN  SHD       TPR       FPR   FDR           scenario  \
# 0  2.0  0.0  1.0  6.0  1.0  0.666667  0.000000  0.00  moderation_effect
# 1  3.0  1.0  0.0  5.0  1.0  1.000000  0.166667  0.25  moderation_effect
# 2  NaN  NaN  NaN  NaN  NaN       NaN       NaN   NaN  moderation_effect
# 3  2.0  0.0  1.0  6.0  1.0  0.666667  0.000000  0.00  moderation_effect
# 4  3.0  0.0  0.0  6.0  0.0  1.000000  0.000000  0.00  moderation_effect
#
#                     dataset  ... skel_FPR  skel_FDR  orient_TP  orient_FP  \
# 0  arthritis_pain_reduction  ...      NaN       NaN        NaN        NaN
# 1  arthritis_pain_reduction  ...      NaN       NaN        NaN        NaN
# 2  arthritis_pain_reduction  ...      0.0       0.0        4.0        0.0
# 3  arthritis_pain_reduction  ...      NaN       NaN        NaN        NaN
# 4  arthritis_pain_reduction  ...      NaN       NaN        NaN        NaN
#
#    orient_FN  orient_TN  orient_SHD  orient_TPR  orient_FPR  orient_FDR
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
# 2        2.0        0.0         2.0    0.666667         NaN         0.0
# 3        NaN        NaN         NaN         NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 27 columns]

# %%
all_scores.columns
# Out:
# Index(['TP', 'FP', 'FN', 'TN', 'SHD', 'TPR', 'FPR', 'FDR', 'scenario',
#        'dataset', 'algo', 'skel_TP', 'skel_FP', 'skel_FN', 'skel_TN',
#        'skel_SHD', 'skel_TPR', 'skel_FPR', 'skel_FDR', 'orient_TP',
#        'orient_FP', 'orient_FN', 'orient_TN', 'orient_SHD', 'orient_TPR',
#        'orient_FPR', 'orient_FDR'],
#       dtype='object')

# %%
#use skel_TP, skel_FP, skel_FN, etc as standard metrics for fci runs
fci_experiments=all_scores["algo"] == "fci"
for metric in ["TP", "FP", "FN", "TN", "SHD", "TPR", "FPR", "FDR"]:
    all_scores.loc[fci_experiments, metric] = np.where(
        all_scores.loc[fci_experiments, metric].isna(),
        all_scores.loc[fci_experiments, f"skel_{metric}"],
        all_scores.loc[fci_experiments, metric])

# %%
all_scores.loc[fci_experiments]
# Out:
#        TP   FP    FN    TN   SHD       TPR       FPR       FDR  \
# 2     4.0  0.0   2.0   3.0   2.0  0.666667  0.000000  0.000000
# 8     4.0  0.0   6.0   6.0   6.0  0.400000  0.000000  0.000000
# 14    6.0  0.0   0.0  10.0   0.0  1.000000  0.000000  0.000000
# 20    4.0  0.0   6.0   6.0   6.0  0.400000  0.000000  0.000000
# 26    4.0  0.0   6.0   6.0   6.0  0.400000  0.000000  0.000000
# 32    6.0  0.0   2.0   8.0   2.0  0.750000  0.000000  0.000000
# 40    6.0  2.0   0.0   8.0   2.0  1.000000  0.200000  0.250000
# 41    6.0  2.0   2.0   6.0   4.0  0.750000  0.250000  0.250000
# 50    4.0  0.0   0.0   5.0   0.0  1.000000  0.000000  0.000000
# 56    4.0  0.0   2.0   3.0   2.0  0.666667  0.000000  0.000000
# 62   10.0  6.0   8.0  25.0  14.0  0.555556  0.193548  0.375000
# 68    4.0  0.0   6.0   6.0   6.0  0.400000  0.000000  0.000000
# 74    4.0  0.0   6.0   6.0   6.0  0.400000  0.000000  0.000000
# 80    4.0  0.0   2.0  10.0   2.0  0.666667  0.000000  0.000000
# 85    8.0  2.0  10.0  16.0  12.0  0.444444  0.111111  0.200000
# 91    6.0  2.0   2.0   6.0   4.0  0.750000  0.250000  0.250000
# 97    6.0  4.0  12.0  14.0  16.0  0.333333  0.222222  0.400000
# 103   0.0  4.0   6.0   6.0  10.0  0.000000  0.400000  1.000000
# 109  10.0  2.0   6.0  31.0   8.0  0.625000  0.060606  0.166667
# 115   6.0  0.0   0.0  10.0   0.0  1.000000  0.000000  0.000000
# 121   4.0  0.0   2.0   3.0   2.0  0.666667  0.000000  0.000000
# 127   4.0  0.0   2.0   3.0   2.0  0.666667  0.000000  0.000000
# 132   8.0  2.0  10.0  16.0  12.0  0.444444  0.111111  0.200000
# 138   8.0  2.0   0.0   6.0   2.0  1.000000  0.250000  0.200000
# 143   8.0  2.0  10.0  16.0  12.0  0.444444  0.111111  0.200000
# 149  10.0  2.0   6.0  31.0   8.0  0.625000  0.060606  0.166667
# 155   6.0  2.0   2.0   6.0   4.0  0.750000  0.250000  0.250000
# 161   4.0  0.0   2.0  10.0   2.0  0.666667  0.000000  0.000000
# 167   6.0  0.0   0.0   3.0   0.0  1.000000  0.000000  0.000000
# 173   6.0  0.0   0.0  10.0   0.0  1.000000  0.000000  0.000000
# 179  12.0  4.0   4.0  29.0   8.0  0.750000  0.121212  0.250000
# 185   6.0  0.0   0.0  10.0   0.0  1.000000  0.000000  0.000000
# 191  12.0  4.0  20.0  28.0  24.0  0.375000  0.125000  0.250000
# 197   4.0  0.0   0.0   5.0   0.0  1.000000  0.000000  0.000000
# 203   6.0  0.0   0.0  10.0   0.0  1.000000  0.000000  0.000000
# 209   6.0  8.0  12.0  23.0  20.0  0.333333  0.258065  0.571429
# 215   4.0  0.0   0.0   5.0   0.0  1.000000  0.000000  0.000000
# 220   8.0  2.0  10.0  16.0  12.0  0.444444  0.111111  0.200000
# 226   4.0  0.0   0.0   5.0   0.0  1.000000  0.000000  0.000000
#
#                          scenario                         dataset  ...  \
# 2               moderation_effect        arthritis_pain_reduction  ...
# 8                    domain_shift                 arthritis_trial  ...
# 14          necessity_sufficiency                bridge_integrity  ...
# 20                   domain_shift                    cardio_trial  ...
# 26                   domain_shift               cholesterol_trial  ...
# 32       counterfactual_reasoning              climate_impact_sem  ...
# 40            causal_direction_iv              clinical_trial_sem  ...
# 41       counterfactual_reasoning              clinical_trial_sem  ...
# 50         dag_structure_markequi      dag_structure_markequi_sem  ...
# 56              moderation_effect    depression_symptom_reduction  ...
# 62                  casual_effect             device_failure_data  ...
# 68                   domain_shift                  diabetes_trial  ...
# 74                   domain_shift                domain_shift_sem  ...
# 80            causal_direction_iv                   ecommerce_sem  ...
# 85             treatment_mediator               economic_stimulus  ...
# 91       counterfactual_reasoning       education_performance_sem  ...
# 97             treatment_mediator        education_subsidy_policy  ...
# 103           causal_direction_iv                 environment_sem  ...
# 109  mediation_outcome_confounder     exercise_intervention_study  ...
# 115         necessity_sufficiency              factory_monitoring  ...
# 121             moderation_effect       hypertension_bp_reduction  ...
# 127             moderation_effect    infection_bacteria_reduction  ...
# 132            treatment_mediator  infrastructure_spending_policy  ...
# 138      counterfactual_reasoning          investment_outcome_sem  ...
# 143            treatment_mediator             job_training_policy  ...
# 149  mediation_outcome_confounder         language_learning_study  ...
# 155      counterfactual_reasoning       manufacturing_quality_sem  ...
# 161           causal_direction_iv                   marketing_sem  ...
# 167             moderation_effect           moderation_effect_sem  ...
# 173         necessity_sufficiency                  network_health  ...
# 179  mediation_outcome_confounder         nutrition_program_study  ...
# 185         necessity_sufficiency                patient_recovery  ...
# 191           sequential_mediator    sequential_mediation_dataset  ...
# 197        dag_structure_markequi    sleep_alertness_productivity  ...
# 203         necessity_sufficiency                      stress_sem  ...
# 209                 casual_effect           student_tutoring_data  ...
# 215        dag_structure_markequi   study_comprehension_testscore  ...
# 220            treatment_mediator            tax_incentive_policy  ...
# 226        dag_structure_markequi             web_traffic_revenue  ...
#
#      skel_FPR  skel_FDR  orient_TP  orient_FP  orient_FN  orient_TN  \
# 2    0.000000  0.000000        4.0        0.0        2.0        0.0
# 8    0.000000  0.000000        4.0        0.0        6.0        0.0
# 14   0.000000  0.000000        6.0        0.0        0.0        0.0
# 20   0.000000  0.000000        4.0        0.0        6.0        0.0
# 26   0.000000  0.000000        4.0        0.0        6.0        0.0
# 32   0.000000  0.000000        0.0        0.0        8.0        0.0
# 40   0.200000  0.250000        4.0        0.0        2.0        0.0
# 41   0.250000  0.250000        4.0        2.0        2.0        0.0
# 50   0.000000  0.000000        0.0        0.0        4.0        0.0
# 56   0.000000  0.000000        4.0        0.0        2.0        0.0
# 62   0.193548  0.375000        4.0        2.0       12.0        0.0
# 68   0.000000  0.000000        4.0        0.0        6.0        0.0
# 74   0.000000  0.000000        4.0        0.0        6.0        0.0
# 80   0.000000  0.000000        0.0        0.0        6.0        0.0
# 85   0.111111  0.200000        4.0        2.0       12.0        0.0
# 91   0.250000  0.250000        4.0        2.0        2.0        0.0
# 97   0.222222  0.400000        2.0        0.0       16.0        0.0
# 103  0.400000  1.000000        0.0        0.0        6.0        0.0
# 109  0.060606  0.166667        4.0        2.0       10.0        0.0
# 115  0.000000  0.000000        6.0        0.0        0.0        0.0
# 121  0.000000  0.000000        4.0        0.0        2.0        0.0
# 127  0.000000  0.000000        4.0        0.0        2.0        0.0
# 132  0.111111  0.200000        4.0        2.0       12.0        0.0
# 138  0.250000  0.200000        2.0        2.0        4.0        0.0
# 143  0.111111  0.200000        8.0        0.0       10.0        0.0
# 149  0.060606  0.166667        8.0        0.0        8.0        0.0
# 155  0.250000  0.250000        4.0        2.0        2.0        0.0
# 161  0.000000  0.000000        0.0        0.0        6.0        0.0
# 167  0.000000  0.000000        0.0        0.0        6.0        0.0
# 173  0.000000  0.000000        6.0        0.0        0.0        0.0
# 179  0.121212  0.250000       12.0        0.0        4.0        0.0
# 185  0.000000  0.000000        6.0        0.0        0.0        0.0
# 191  0.125000  0.250000        8.0        0.0       24.0        0.0
# 197  0.000000  0.000000        0.0        0.0        4.0        0.0
# 203  0.000000  0.000000        6.0        0.0        0.0        0.0
# 209  0.258065  0.571429        0.0        4.0       14.0        0.0
# 215  0.000000  0.000000        0.0        0.0        4.0        0.0
# 220  0.111111  0.200000        4.0        2.0       12.0        0.0
# 226  0.000000  0.000000        0.0        0.0        4.0        0.0
#
#      orient_SHD  orient_TPR  orient_FPR  orient_FDR
# 2           2.0    0.666667         NaN    0.000000
# 8           6.0    0.400000         NaN    0.000000
# 14          0.0    1.000000         NaN    0.000000
# 20          6.0    0.400000         NaN    0.000000
# 26          6.0    0.400000         NaN    0.000000
# 32          8.0    0.000000         NaN         NaN
# 40          2.0    0.666667         NaN    0.000000
# 41          4.0    0.666667         1.0    0.333333
# 50          4.0    0.000000         NaN         NaN
# 56          2.0    0.666667         NaN    0.000000
# 62         14.0    0.250000         1.0    0.333333
# 68          6.0    0.400000         NaN    0.000000
# 74          6.0    0.400000         NaN    0.000000
# 80          6.0    0.000000         NaN         NaN
# 85         14.0    0.250000         1.0    0.333333
# 91          4.0    0.666667         1.0    0.333333
# 97         16.0    0.111111         NaN    0.000000
# 103         6.0    0.000000         NaN         NaN
# 109        12.0    0.285714         1.0    0.333333
# 115         0.0    1.000000         NaN    0.000000
# 121         2.0    0.666667         NaN    0.000000
# 127         2.0    0.666667         NaN    0.000000
# 132        14.0    0.250000         1.0    0.333333
# 138         6.0    0.333333         1.0    0.500000
# 143        10.0    0.444444         NaN    0.000000
# 149         8.0    0.500000         NaN    0.000000
# 155         4.0    0.666667         1.0    0.333333
# 161         6.0    0.000000         NaN         NaN
# 167         6.0    0.000000         NaN         NaN
# 173         0.0    1.000000         NaN    0.000000
# 179         4.0    0.750000         NaN    0.000000
# 185         0.0    1.000000         NaN    0.000000
# 191        24.0    0.250000         NaN    0.000000
# 197         4.0    0.000000         NaN         NaN
# 203         0.0    1.000000         NaN    0.000000
# 209        18.0    0.000000         1.0    1.000000
# 215         4.0    0.000000         NaN         NaN
# 220        14.0    0.250000         1.0    0.333333
# 226         4.0    0.000000         NaN         NaN
#
# [39 rows x 27 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid", context="talk")

order = sorted(all_scores["algo"].unique())
palette = sns.color_palette("tab10")

fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharey=False)

sns.violinplot(
    data=all_scores,
    x="algo", y="TPR",
    order=order,
    inner="box",    #boxplot embedded in violin     
    cut=0,
    palette=palette,
    ax=axes[0],
    inner_kws=dict(color="black")
)
axes[0].set_title("True Positive Rate (TPR)")
axes[0].set_xlabel("Algorithm")
axes[0].set_ylabel("TPR")
axes[0].tick_params(axis="x", rotation=45) #rotate x labels to prevent overlap

sns.violinplot(
    data=all_scores,
    x="algo", y="FPR",
    order=order,
    inner="box",
    cut=0,
    palette=palette,
    ax=axes[1],
    inner_kws=dict(color="black")
)
axes[1].set_title("False Positive Rate (FPR)")
axes[1].set_xlabel("Algorithm")
axes[1].set_ylabel("FPR")
axes[1].tick_params(axis="x", rotation=45) #rotate x labels to prevent overlap

plt.tight_layout()
plt.savefig("tpr_fpr_violinplots.png", dpi=600, bbox_inches="tight")
plt.show()
# Out:
# /tmp/dcs-tmp.u2200504/ipykernel_714460/4173400802.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/dcs-tmp.u2200504/ipykernel_714460/4173400802.py:11: UserWarning: The palette list has more values (10) than needed (6), which may not be intended.
#   sns.violinplot(
# /tmp/dcs-tmp.u2200504/ipykernel_714460/4173400802.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/dcs-tmp.u2200504/ipykernel_714460/4173400802.py:26: UserWarning: The palette list has more values (10) than needed (6), which may not be intended.
#   sns.violinplot(

# %%
sns.set(style="whitegrid", context="talk")

plt.figure(figsize=(6, 5))
palette = sns.color_palette("tab10")

sns.scatterplot(
    data=all_scores,
    x="FPR", y="TPR",
    hue="algo",
    style="algo",
    palette = sns.color_palette("tab10"),
    s=60
)
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("TPR vs FPR across algorithms and datasets")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.savefig("tpr_fpr_scatter.png",dpi=600, bbox_inches="tight")
plt.show()
# Out:
# /tmp/dcs-tmp.u2200504/ipykernel_714460/4062091071.py:6: UserWarning: The palette list has more values (10) than needed (6), which may not be intended.
#   sns.scatterplot(

# %%
palette = sns.color_palette("tab10")

g = sns.FacetGrid(
    all_scores,
    col="algo",
    col_wrap=3,
    height=3,
    palette = sns.color_palette("tab10"),
    sharex=True,
    sharey=True
)
g.map_dataframe(sns.scatterplot, x="FPR", y="TPR")
g.set_axis_labels("FPR", "TPR")
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("TPR against FPR by algorithm")
plt.show()

# %%
import pandas as pd

tpr_table = (
    all_scores
    .groupby(["algo", "dataset"])["TPR"]
    .mean()
    .unstack("dataset")
)

fpr_table = (
    all_scores
    .groupby(["algo", "dataset"])["FPR"]
    .mean()
    .unstack("dataset")
)

shd_table = (
    all_scores
    .groupby(["algo", "dataset"])["SHD"]
    .mean()
    .unstack("dataset")
)


plt.figure(figsize=(8, 4))
sns.heatmap(
    tpr_table,
    #annot=True,
    fmt=".2f",
    cmap="viridis",
    cbar_kws={"label": "TPR"}
)
plt.xlabel("Dataset")
plt.ylabel("Algorithm")
plt.title("Mean TPR per algorithm and dataset")
plt.show()

# %%
import pandas as pd
from pathlib import Path

#set project root as .../recidivism-causal
project_root = Path("..").resolve()

#set causal pitfalls root
csv_path = project_root / "data" / "raw" / "NIJ_s_Recidivism_Chall.csv"

# %%
df = pd.read_csv(csv_path)
blank_cols = df.columns[df.isna().any()]
print(blank_cols)
# Out:
# Index(['Gang_Affiliated', 'Supervision_Risk_Score_First',
#        'Supervision_Level_First', 'Prison_Offense', 'Avg_Days_per_DrugTest',
#        'DrugTests_THC_Positive', 'DrugTests_Cocaine_Positive',
#        'DrugTests_Meth_Positive', 'DrugTests_Other_Positive',
#        'Percent_Days_Employed', 'Jobs_Per_Year'],
#       dtype='object')

# %%
count_blank = df.isna().sum()
print(count_blank)
print((count_blank/25835)*100)
# Out:
# ID                                                      0
# Gender                                                  0
# Race                                                    0
# Age_at_Release                                          0
# Residence_PUMA                                          0
# Gang_Affiliated                                      3167
# Supervision_Risk_Score_First                          475
# Supervision_Level_First                              1720
# Education_Level                                         0
# Dependents                                              0
# Prison_Offense                                       3277
# Prison_Years                                            0
# Prior_Arrest_Episodes_Felony                            0
# Prior_Arrest_Episodes_Misd                              0
# Prior_Arrest_Episodes_Violent                           0
# Prior_Arrest_Episodes_Property                          0
# ...

# %% [raw]
# Neural network models ("Team Sherrill"):
# imputation strategy uses mean values stratified by gender and race (e.g white male, black female etc.)
# Where gender stratification was unavailable (i.e gang affiliation), done with just race.
# Categorical variables use one-hot encoding.
#
# XGBoost team ("Team Tim"):
# XGBoost only handles numeric features
# Categorical -> numeric
# Ordinal categorical factors such as age at release buckets converted by taking LB of age range and converting to integer
# One hot encoding used for anything with an unlear numeric interpretation (Supervision_Level_First, Education_Level, Prison_Offense, Residence_PUMA).
# Imputation strategy used modal values of the feature.
# Missing features were retained by adding an extra feature (e.g Jobs_Per_Year -> Jobs_Per_Year_miss)
# Modelled discrepencies (i.e non zero amount of viol for move without permission but recorded residence changes of 0). Residence change discrepancy 1.5x more likely to recidivate at 3 years than population.
#
# Team CrescentStar:
# Used external statistics, census information from PUMA, crime statistics, poverty data, hospital, unemployment etc.
# Ordinal variables were converted via one-hot encoding.
# uses polynomial contrasts(???)
# No imputation for XGBoost, lostic regression used median values for imputation
#
# Team DataRobot:
# One hot encoding for categorical data
# Numeric features impute missing values with the median (where there are 50 or more samples)
# Indicator variables were created to identify missing values.
# Imputed features may be scaled using scaled rounding (rounding to log scale)
#
# Team DEAP:
# used puma level census data
# some numerical categorical ordinal values were transformed to numerical values, non numerical categorical values were one hot encoded
# Supervision risk score was imputed using the median and an additional variable was used to flag missing or not.
# The remaining variables were not imputed and additional variables were created to flag "unknowns"
#
# Team JianyeGe:
# missing data automatically imputed according to classifier. (Logistic, LMT, MultiClassClassifier, ClassificationViaRegression).
#
# Team MattMarifelSora:
# Imputed missing values, converted strings to integers, discretized continuous variables
# Heirarchical Bayesian target encoding was used to convert categorical variables into numerical values by mapping categories to the mean target value of the category. Additional categories were created by partitioning categories according to hierarchy. E.g Race -> gang affiliation -> gender
# imputation strategy not explicitly mentioned.
#
# Team MNLB:
# Removed all rows (330) with missing supervision risk score
# gang affiliation missing values were set to false.
# supervision level first and prison offense were imputed based on logistic regression prediction.
#
# Team Oracle:
# Categorical -> one hot encoding
# Ordinal -> integer encoded
# Numerical values -> scaled to be 0<=x<=1
# Missing values imputed using SimpleImputer library (strategy not specified?)
#
# Team PASDA:
# nominal features treated missing values as a level in and of itself.
# for missing supervision risk scores, an integer value of 10 was assigned (methodology? not particularly mentioned)
# mean imputation was used for missing percent of positive drug tests, median imputation was used for missing average days per drug test (discussion about selection of strategy not mentioned)
#
# Team SASInstitute:
# Ordinal variables were encoded
# Missing values were imputed with either 'missing' (Gang Affiliation and Prison offense) or -1 in the cases of the other variables.
#
# Team Klus:
# Re-levelled categorical variables, collapsed categories into ordinal variables "to preserve degrees of freedom"
# used the 'mice' package in R to impute data. model coefficients and standard error estimates averaged over 5 imputated data sets. "Each variable has its own imputation model. Built-in imputation models are provided for continuous data (predictive mean matching, normal), binary data (logistic regression), unordered categorical data (polytomous logistic regression) and ordered categorical data (proportional odds)." (src: https://cran.r-project.org/web/packages/mice/index.html)
# more extensive the missingness, less reliable results of imputation.
#
# Team VTISE:
# imputation method not explicitly detailed...

# %% [raw]
# Important notes about missingness:
# Gang_Affiliated not recorded for any females
# Missing data for one drug test => missing data for all other drug tests.
# Jobs_per_year_miss derived feature was important according to XGBoost approach
# perfect predictor (due to leakage? reported by team PASDA) - missing value for percent days employed or jobs per year indicated no recidivism.

# %%
#conditional sampling imputation for gang affiliation
data = pd.read_csv(csv_path)
headers = list(data.columns)
print(headers)

from sdv.metadata import Metadata
from sdv.single_table import GaussianCopulaSynthesizer 
from sdv.sampling import DataFrameCondition

# build metadata
metadata = Metadata.detect_from_dataframe(
    data = data,
    table_name="NIJ"
)

synthesizer = GaussianCopulaSynthesizer(metadata=metadata)
synthesizer.fit(data)

#set conditioning columns for gang imputation
cond_cols_gang = [
    col for col in data.columns
    if col not in ["ID", "Gender", "Gang_Affiliated", 
                   "Recidivism_Within_3years", "Recidivism_Arrest_Year1",
                  "Recidivism_Arrest_Year2", "Recidivism_Arrest_Year3",
                  "Training_Sample"] #exclude these columns
]

#create mask for where rows where gang affiliation info is missing
missingness_mask= data["Gang_Affiliated"].isna()
known = data.loc[missingness_mask, cond_cols_gang]

#each row is one scenario to sample
conditions_df = DataFrameCondition(
    table_name="NIJ",
    dataframe=known
)

synthetic_conditional_gang=synthesizer.sample_from_conditions(
    conditions=[conditions_df]
)

#insert imputed values
gang_imputed=data.copy()
gang_imputed.loc[missingness_mask, "Gang_Affiliated"]=(
    synthetic_conditional_gang["Gang_Affiliated"].values
)

#add column to retain missingness information and save gang_imputed dataframe to csv
gang_imputation_flag = missingness_mask.astype(int)
gang_imputed["Gang_Affiliated_Missing"] = gang_imputation_flag
gang_imputed.to_csv("NIJ_gang_imputed.csv", index=False)
# Out:
# ['ID', 'Gender', 'Race', 'Age_at_Release', 'Residence_PUMA', 'Gang_Affiliated', 'Supervision_Risk_Score_First', 'Supervision_Level_First', 'Education_Level', 'Dependents', 'Prison_Offense', 'Prison_Years', 'Prior_Arrest_Episodes_Felony', 'Prior_Arrest_Episodes_Misd', 'Prior_Arrest_Episodes_Violent', 'Prior_Arrest_Episodes_Property', 'Prior_Arrest_Episodes_Drug', 'Prior_Arrest_Episodes_PPViolationCharges', 'Prior_Arrest_Episodes_DVCharges', 'Prior_Arrest_Episodes_GunCharges', 'Prior_Conviction_Episodes_Felony', 'Prior_Conviction_Episodes_Misd', 'Prior_Conviction_Episodes_Viol', 'Prior_Conviction_Episodes_Prop', 'Prior_Conviction_Episodes_Drug', 'Prior_Conviction_Episodes_PPViolationCharges', 'Prior_Conviction_Episodes_DomesticViolenceCharges', 'Prior_Conviction_Episodes_GunCharges', 'Prior_Revocations_Parole', 'Prior_Revocations_Probation', 'Condition_MH_SA', 'Condition_Cog_Ed', 'Condition_Other', 'Violations_ElectronicMonitoring', 'Violations_Instruction', 'Violations_FailToReport', 
# ...

# %%
print(data["Gang_Affiliated"].isna().sum())
remain_blank=gang_imputed["Gang_Affiliated"].isna().sum()
print(remain_blank)
total = len(gang_imputed)
print(remain_blank/total*100) #~1.5% of data is still blank after imputation
# Out:
# 3167
# 389
# 1.5057093090768339

# %%
#imputing drug related columns
cols_to_impute = [
    "Avg_Days_per_DrugTest",
    "DrugTests_THC_Positive",
    "DrugTests_Cocaine_Positive",
    "DrugTests_Meth_Positive",
    "DrugTests_Other_Positive",
]

cond_cols_drug = [
    col for col in data.columns
    if col not in ["ID", "Gang_Affiliated", 
                   "Recidivism_Within_3years", "Recidivism_Arrest_Year1",
                  "Recidivism_Arrest_Year2", "Recidivism_Arrest_Year3",
                  "Training_Sample"] + cols_to_impute #exclude these columns, dont use gang affiliated as we have fiddled with it
]

drug_imputed = gang_imputed.copy()

for col in cols_to_impute:
    # rows where this column is missing
    missing_mask = gang_imputed[col].isna()
    if missing_mask.sum() == 0:
        continue  # nothing to do for this column

    known_part = gang_imputed.loc[missing_mask, cond_cols_drug]

    conditions_df = DataFrameCondition(
        table_name="recidivism",
        dataframe=known_part
    )

    synthetic_conditional = synthesizer.sample_from_conditions(
        conditions=[conditions_df]
    )

    # copy back only this column’s synthetic values
    drug_imputed.loc[missing_mask, col] = synthetic_conditional[col].values
    #retain missingness information
    col_imputation_flag = missing_mask.astype(int)
    drug_imputed[f"{col}_Missing"] = col_imputation_flag

drug_imputed.to_csv("NIJ_drug_imputed.csv", index=False)
# Out:
# ...
# Sampling conditions: 100%|██████████| 5172/5172 [15:01<00:00,  5.74it/s]

# %%
drug_imputed
# Out:
#           ID Gender   Race Age_at_Release  Residence_PUMA Gang_Affiliated  \
# 0          1      M  BLACK          43-47              16           False
# 1          2      M  BLACK          33-37              16           False
# 2          3      M  BLACK    48 or older              24           False
# 3          4      M  WHITE          38-42              16           False
# 4          5      M  WHITE          33-37              16           False
# ...      ...    ...    ...            ...             ...             ...
# 25830  26756      M  BLACK          23-27               9           False
# 25831  26758      M  WHITE          38-42              25           False
# 25832  26759      M  BLACK          33-37              15           False
# 25833  26760      F  WHITE          33-37              15             NaN
# 25834  26761      M  WHITE          28-32              12           False
#
#        Supervision_Risk_Score_First Supervision_Level_First  \
# ...
